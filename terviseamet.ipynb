# %% [markdown]
# # Preparation of the drinking water quality data

# %%
# Imports
from PIL import Image
import pandas as pd
import numpy as np
import os,sys

# %%
# Read raw files
raw_path = "./raw_data/terviseamet"
raw_files = os.listdir(raw_path)

original_columns = pd.read_csv(os.path.join(raw_path, raw_files[0]))

raw_filelist = []
for f in raw_files:
    df = pd.read_csv(os.path.join(raw_path, f))

    # select columns and translate into english
    col_map = {
        'id': 'test_id',
        'veevark_id': 'station_id', 
        'veeliik': 'water_type', 
        'proovivotu_aeg': 'date',
        'proovivotu_metoodika': 'test_method', 
        'id3': 'indicator_id',
        'nimetus4': 'indicator_name',
        'sisaldus': 'value',
        'yhik': 'unit',
        'hinnang5': 'assessment'
        }
    df = df[col_map.keys()]
    df.rename(columns=col_map, inplace=True)
    
    # Add year variable
    df['date'] = pd.to_datetime(df['date'])
    df['year'] = df.date.dt.year

    # Add df to list for concatenation later
    raw_filelist.append(df)

long_df = pd.concat(raw_filelist, ignore_index=True)
long_df
# Out:
# /tmp/ipykernel_842/3289904645.py:9: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(raw_path, f))
# /tmp/ipykernel_842/3289904645.py:9: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(raw_path, f))
# /tmp/ipykernel_842/3289904645.py:9: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(raw_path, f))
# /tmp/ipykernel_842/3289904645.py:9: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(raw_path, f))
#         test_id  station_id water_type       date test_method  indicator_id  \
# 0        276444         302  Joogivesi 2022-05-07         NaN           241
# 1        276444         302  Joogivesi 2022-05-07         NaN           112
# 2        276444         302  Joogivesi 2022-05-07         NaN           131
# 3        276444         302  Joogivesi 2022-05-07         NaN            16
# 4        276444         302  Joogivesi 2022-05-07         NaN            51
# ...         ...         ...        ...        ...         ...           ...
# 504185   173704         306  Joogivesi 2018-01-01         NaN           131
# 504186   173704         306  Joogivesi 2018-01-01         NaN            16
# 504187   173878         306  Joogivesi 2018-01-01         NaN             7
# 504188   173878         306  Joogivesi 2018-01-01         NaN             4
# 504189   173878         306  Joogivesi 2018-01-01         NaN            57
#
#                                 indicator_name value           unit  \
# 0                       Maitse (lahjendusaste)     1  lahjendusaste
# 1                         Lõhn (lahjendusaste)     1  lahjendusaste
# 2                        Värvus (Pt/Co skaala)     3        mg/l Pt
# 3                                           pH   7.7        pH ühik
# 4                              Elektrijuhtivus   630          μS/cm
# ...                                        ...   ...            ...
# 504185                   Värvus (Pt/Co skaala)     3        mg/l Pt
# 504186                                      pH  7.22        pH ühik
# 504187  Clostridium perfringens (koos eostega)     0      PMÜ/100ml
# 504188                        Escherichia coli     0     PMÜ/100 ml
# 504189                   Coli-laadsed bakterid     0     PMÜ/100 ml
#
#              assessment  year
# 0       vastab nõuetele  2022
# 1       vastab nõuetele  2022
# 2       vastab nõuetele  2022
# 3       vastab nõuetele  2022
# 4       vastab nõuetele  2022
# ...                 ...   ...
# 504185  vastab nõuetele  2018
# 504186  vastab nõuetele  2018
# 504187  vastab nõuetele  2018
# 504188  vastab nõuetele  2018
# 504189  vastab nõuetele  2018
#
# [504190 rows x 11 columns]

# %%
# How many tests per year per station_id
long_df.groupby(by=['station_id', 'year']).test_id.unique()
# Out:
# station_id  year
# 162         2014                                [80238, 80290, 61616]
#             2015                              [106003, 106041, 98823]
#             2016                             [133003, 131795, 122653]
#             2017                                     [137400, 137538]
#             2018    [182057, 182240, 177174, 177336, 168987, 16925...
#                                           ...
# 2604        2022                                     [268222, 268532]
# 2643        2022                                             [274479]
# 2676        2022                                     [274169, 274168]
# 2678        2021                             [256134, 256136, 256138]
# 2679        2022                                             [275717]
# Name: test_id, Length: 9237, dtype: object

# %%
long_df.value.dtype
# Out:
# dtype('O')

# %% [markdown]
# # What indicators to keep

# %%
# Keep only 2017-2021
period_df = long_df[(long_df.year>=2018) & (long_df.year < 2022)]

# %%
# Which indicators exist for all years
inds_per_year_df = period_df.groupby(by=['indicator_name', 'year']).size().sort_values(ascending=False).to_frame(name='size')
inds_per_year_wide = inds_per_year_df.pivot_table(
    index = ['indicator_name'],
    columns = 'year',
    values = 'size'
)

# Indicators that have more than n instances for all years
inds_that_exist_all_years = inds_per_year_wide.dropna()
for y in period_df.year.unique():
    inds_that_exist_all_years = inds_that_exist_all_years[inds_that_exist_all_years[y]>=1000]
indicators_to_keep = inds_that_exist_all_years.index
indicators_to_keep
# Out:
# Index(['Ammoonium', 'Coli-laadsed bakterid', 'Elektrijuhtivus',
#        'Escherichia coli', 'Hägusus (NTU)', 'Kolooniate arv 22 °C',
#        'Lõhn (lahjendusaste)', 'Maitse (lahjendusaste)', 'Raud',
#        'Värvus (Pt/Co skaala)', 'pH'],
#       dtype='object', name='indicator_name')

# %%
# Dataframe with only top indicators
rows_to_keep = [iname in indicators_to_keep for iname in period_df.indicator_name]
top_ind_df = period_df[rows_to_keep] 
top_ind_df
# Out:
#         test_id  station_id water_type                date  \
# 13627    212401        1724  Joogivesi 2019-12-31 00:00:00
# 13628    208314         306  Joogivesi 2019-12-30 08:30:00
# 13629    208314         306  Joogivesi 2019-12-30 08:30:00
# 13630    208314         306  Joogivesi 2019-12-30 08:30:00
# 13632    208314         306  Joogivesi 2019-12-30 08:30:00
# ...         ...         ...        ...                 ...
# 504184   173704         306  Joogivesi 2018-01-01 00:00:00
# 504185   173704         306  Joogivesi 2018-01-01 00:00:00
# 504186   173704         306  Joogivesi 2018-01-01 00:00:00
# 504188   173878         306  Joogivesi 2018-01-01 00:00:00
# 504189   173878         306  Joogivesi 2018-01-01 00:00:00
#
#                              test_method  indicator_id         indicator_name  \
# 13627                                NaN            40   Kolooniate arv 22 °C
# 13628   EVS-ISO 5667-5, EVS-EN ISO 19458           112   Lõhn (lahjendusaste)
# 13629   EVS-ISO 5667-5, EVS-EN ISO 19458            56          Hägusus (NTU)
# 13630   EVS-ISO 5667-5, EVS-EN ISO 19458             1                   Raud
# 13632   EVS-ISO 5667-5, EVS-EN ISO 19458           131  Värvus (Pt/Co skaala)
# ...                                  ...           ...                    ...
# 504184                               NaN            57  Coli-laadsed bakterid
# 504185                               NaN           131  Värvus (Pt/Co skaala)
# 504186                               NaN            16                     pH
# 504188                               NaN             4       Escherichia coli
# 504189                               NaN            57  Coli-laadsed bakterid
#
#        value           unit       assessment  year
# 13627     87       PMÜ/1 ml  vastab nõuetele  2019
# 13628      1  lahjendusaste  vastab nõuetele  2019
# 13629    1.0            NTU  vastab nõuetele  2019
# 13630     18           µg/l  vastab nõuetele  2019
# 13632      2        mg/l Pt  vastab nõuetele  2019
# ...      ...            ...              ...   ...
# 504184     0     PMÜ/100 ml  vastab nõuetele  2018
# 504185     3        mg/l Pt  vastab nõuetele  2018
# 504186  7.22        pH ühik  vastab nõuetele  2018
# 504188     0     PMÜ/100 ml  vastab nõuetele  2018
# 504189     0     PMÜ/100 ml  vastab nõuetele  2018
#
# [115688 rows x 11 columns]

# %%
# Pivot table for test & indicator
single_test_wide = top_ind_df[['test_id', 'indicator_name', 'value']].pivot_table(
    index = 'test_id',
    columns = 'indicator_name',
    values = 'value'
)
# Out:
# /tmp/ipykernel_842/1162552586.py:2: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   single_test_wide = top_ind_df[['test_id', 'indicator_name', 'value']].pivot_table(

# %%
# How many measurements per station per year
ind_by_year = top_ind_df.groupby(by=['indicator_name', 'year']).size()

# %%
# Value column to numeric and errors to NaN
top_ind_df['value'] = pd.to_numeric(top_ind_df['value'], errors='coerce')
# Out:
# /tmp/ipykernel_842/539291268.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_ind_df['value'] = pd.to_numeric(top_ind_df['value'], errors='coerce')

# %% [markdown]
# # Wide data

# %%
# indicator_name + year variable

# %%
# Keep only relevant variables
vars_for_wide = ['station_id', 'indicator_name', 'value', 'year']
wide_df = top_ind_df[vars_for_wide].pivot_table(
    index = ['station_id', 'year'],
    columns = 'indicator_name',
    values = 'value',
    aggfunc = np.nanmax
)

# %%
# Keep only rows that have all the measurement values
cleaned_df = wide_df.dropna()
cleaned_df
# Out:
# indicator_name   Ammoonium  Coli-laadsed bakterid  Elektrijuhtivus  \
# station_id year
# 162        2018       0.12                    0.0            301.0
# 163        2018       0.08                   17.0            821.0
#            2019       0.08                    0.0            716.0
#            2020       0.08                    0.0            671.0
#            2021       0.08                    0.0            626.0
# ...                    ...                    ...              ...
# 2314       2021       0.07                    0.0            300.0
# 2398       2021       0.08                    0.0            273.0
# 2415       2021       0.05                    0.0            447.0
# 2426       2021       0.05                    4.0            503.0
# 2459       2021       0.05                    0.0            385.0
#
# indicator_name   Escherichia coli  Hägusus (NTU)  Kolooniate arv 22 °C  \
# station_id year
# 162        2018               0.0           1.00                   9.0
# 163        2018               0.0           1.00                  13.0
#            2019               0.0           1.18                  12.0
#            2020               0.0           1.90                  12.0
#            2021               0.0           1.24                 136.0
# ...                           ...            ...                   ...
# 2314       2021               0.0           1.00                   0.0
# 2398       2021               0.0           0.50                   4.0
# 2415       2021               0.0           1.00                  12.0
# 2426       2021               0.0           1.00                  31.0
# 2459       2021               0.0           1.00                   0.0
#
# indicator_name   Lõhn (lahjendusaste)  Maitse (lahjendusaste)   Raud  \
# station_id year
# 162        2018                   1.0                     1.0   56.0
# 163        2018                   3.0                     3.0  131.3
#            2019                   1.0                     1.0  109.4
#            2020                   1.0                     1.0   98.0
#            2021                   1.0                     1.0  130.0
# ...                               ...                     ...    ...
# 2314       2021                   1.0                     1.0   27.0
# 2398       2021                   1.0                     1.0   94.1
# 2415       2021                   1.0                     1.0   20.0
# 2426       2021                   1.0                     1.0   20.0
# 2459       2021                   1.0                     1.0   20.0
#
# indicator_name   Värvus (Pt/Co skaala)    pH
# station_id year
# 162        2018                    6.0  7.50
# 163        2018                   14.9  8.07
#            2019                   11.7  8.17
#            2020                   12.1  8.12
#            2021                   10.4  8.15
# ...                                ...   ...
# 2314       2021                    0.0  7.40
# 2398       2021                    8.4  7.59
# 2415       2021                    0.0  7.60
# 2426       2021                    0.0  7.30
# 2459       2021                    0.0  7.20
#
# [714 rows x 11 columns]

# %%
# How many stations have measurements for all years
clean_obs_per_station = cleaned_df.groupby(by='station_id').size().sort_values(ascending=False)
clean_obs_per_station
# Out:
# station_id
# 291     4
# 320     4
# 442     4
# 345     4
# 342     4
#        ..
# 653     1
# 656     1
# 663     1
# 676     1
# 2459    1
# Length: 409, dtype: int64

# %%
indicators_to_keep.keys()

indicator_name_map = {
'Hägusus (NTU)' : 'turbidity', 
'Escherichia coli': 'escherichia_coli', 
'Coli-laadsed bakterid': 'coli-type_bacteria',
'Värvus (Pt/Co skaala)': 'color',
'Raud': 'iron',
'Maitse (lahjendusaste)': 'taste',
'Lõhn (lahjendusaste)': 'smell', 
'pH': 'ph', 
'Elektrijuhtivus': 'conductivity', 
'Ammoonium': 'ammonia', 
'Lõhn (pallides)': 'smell2', 
'Kolooniate arv 22 °C': 'number_of_colonies', 
'Enterokokid': 'enterococci', 
'Coli-laadsed bakterid (Colilert)': 'coli-type_bacteria_colilert', 
'Escherichia coli (Colilert)': 'escherichia-coli_colilert',
'Mangaan': 'manganese', 
'Clostridium perfringens (koos eostega)': 'clostridium_perfringens', 
'Oksüdeeritavus': 'oxidability'
}
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/keljand/andmetalgud/terviseamet.ipynb Cell 18 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/keljand/andmetalgud/terviseamet.ipynb#ch0000011vscode-remote?line=0'>1</a> indicators_to_keep.keys()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/keljand/andmetalgud/terviseamet.ipynb#ch0000011vscode-remote?line=2'>3</a> indicator_name_map = {
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/keljand/andmetalgud/terviseamet.ipynb#ch0000011vscode-remote?line=3'>4</a> 'Hägusus (NTU)' : 'turbidity',
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/keljand/andmetalgud/terviseamet.ipynb#ch0000011vscode-remote?line=4'>5</a> 'Escherichia coli': 'escherichia_coli',
#    (...)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/keljand/andmetalgud/terviseamet.ipynb#ch0000011vscode-remote?line=20'>21</a> 'Oksüdeeritavus': 'oxidability'
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/keljand/andmetalgud/terviseamet.ipynb#ch0000011vscode-remote?line=21'>22</a> }
#
# AttributeError: 'Index' object has no attribute 'keys'
